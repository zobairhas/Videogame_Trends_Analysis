# %%
import pandas as pd

# %%
games_df = pd.read_json("games.json")

# %%
games_df = games_df.transpose()
games_df.head()
# Out:
#                     name  release_date required_age price dlc_count  \
# 906850            Again?   Aug 8, 2018            0  0.49         0
# 906880              goto  Aug 17, 2018            0  1.99         0
# 906920  Political Puzzle   Aug 7, 2018            0  0.99         0
# 906950       Bomb Riders  Aug 29, 2018            0  1.99         0
# 907000     The Navigator   Aug 3, 2018            0   0.0         0
#
#                                      detailed_description  \
# 906850  Again? is easy game for relax with quiet music...
# 906880  <strong>goto</strong> is a minimalistic maze g...
# 906920  Political Puzzle - slide puzzle game. You need...
# 906950  <u>GAMEPLAY</u><br><br>Classic gameplay of the...
# 907000  The Navigator is a 2D puzzle-platformer where ...
#
#                                            about_the_game  \
# 906850  Again? is easy game for relax with quiet music...
# 906880  <strong>goto</strong> is a minimalistic maze g...
# 906920  Political Puzzle - slide puzzle game. You need...
# 906950  <u>GAMEPLAY</u><br><br>Classic gameplay of the...
# 907000  The Navigator is a 2D puzzle-platformer where ...
#
#                                         short_description  \
# 906850                                Just open and play!
# 906880  goto is a minimalistic maze game which leads y...
# 906920  Political Puzzle - slide puzzle game. You need...
# 906950  Bomb Riders - a game in the bomber genre, whic...
# 907000  The Navigator is a 2D puzzle-platformer where ...
#
#                                       supported_languages reviews  ...  \
# 906850                                            English          ...
# 906880  English, French, Italian, German, Spanish - Sp...          ...
# 906920  English<strong>*</strong><br><strong>*</strong...          ...
# 906950  English, French, Italian, German, Spanish - Sp...          ...
# 907000                                            English          ...
#
#        achievements recommendations notes  \
# 906850            0               0
# 906880          100               0
# 906920          100               0
# 906950            6               0
# 907000            0               0
#
#                                                  packages         developers  \
# 906850  [{'title': 'Buy Again?', 'description': '', 's...         [KillGame]
# 906880  [{'title': 'Buy goto', 'description': '', 'sub...  [Alien Jellyfish]
# 906920  [{'title': 'Buy Political Puzzle', 'descriptio...        [Easy game]
# 906950  [{'title': 'Buy Bomb Riders', 'description': '...        [Renderise]
# 907000                                                 []   [Team Navigator]
#
#                publishers                                         categories  \
# 906850   [HandMade Games]                                    [Single-player]
# 906880  [Alien Jellyfish]  [Single-player, Steam Achievements, Partial Co...
# 906920  [Game for people]                [Single-player, Steam Achievements]
# 906950        [Renderise]                                    [Single-player]
# 907000   [Team Navigator]                                    [Single-player]
#
#                                           genres  \
# 906850                                   [Indie]
# 906880                           [Casual, Indie]
# 906920                   [Action, Casual, Indie]
# 906950                                  [Casual]
# 907000  [Adventure, Casual, Free to Play, Indie]
#
#                                               screenshots  \
# 906850  [https://cdn.akamai.steamstatic.com/steam/apps...
# 906880  [https://cdn.akamai.steamstatic.com/steam/apps...
# 906920  [https://cdn.akamai.steamstatic.com/steam/apps...
# 906950  [https://cdn.akamai.steamstatic.com/steam/apps...
# 907000  [https://cdn.akamai.steamstatic.com/steam/apps...
#
#                                                    movies
# 906850  [http://cdn.akamai.steamstatic.com/steam/apps/...
# 906880  [http://cdn.akamai.steamstatic.com/steam/apps/...
# 906920  [http://cdn.akamai.steamstatic.com/steam/apps/...
# 906950  [http://cdn.akamai.steamstatic.com/steam/apps/...
# 907000  [http://cdn.akamai.steamstatic.com/steam/apps/...
#
# [5 rows x 29 columns]

# %%
games_df.dtypes
# Out:
# name                    object
# release_date            object
# required_age            object
# price                   object
# dlc_count               object
# detailed_description    object
# about_the_game          object
# short_description       object
# supported_languages     object
# reviews                 object
# header_image            object
# website                 object
# support_url             object
# support_email           object
# windows                 object
# mac                     object
# linux                   object
# metacritic_score        object
# metacritic_url          object
# achievements            object
# recommendations         object
# notes                   object
# packages                object
# developers              object
# publishers              object
# categories              object
# genres                  object
# screenshots             object
# movies                  object
# dtype: object

# %%
col = ['name', 'release_date', 'price', 'categories', 'genres', 'recommendations', 'metacritic_score', 'windows', 'mac', 'linux']
t_games_df = games_df.loc[:, col]
t_games_df.head()
# Out:
#                     name  release_date price  \
# 906850            Again?   Aug 8, 2018  0.49
# 906880              goto  Aug 17, 2018  1.99
# 906920  Political Puzzle   Aug 7, 2018  0.99
# 906950       Bomb Riders  Aug 29, 2018  1.99
# 907000     The Navigator   Aug 3, 2018   0.0
#
#                                                categories  \
# 906850                                    [Single-player]
# 906880  [Single-player, Steam Achievements, Partial Co...
# 906920                [Single-player, Steam Achievements]
# 906950                                    [Single-player]
# 907000                                    [Single-player]
#
#                                           genres recommendations  \
# 906850                                   [Indie]               0
# 906880                           [Casual, Indie]               0
# 906920                   [Action, Casual, Indie]               0
# 906950                                  [Casual]               0
# 907000  [Adventure, Casual, Free to Play, Indie]               0
#
#        metacritic_score windows    mac  linux
# 906850                0    True  False  False
# 906880                0    True  False  False
# 906920                0    True  False  False
# 906950                0    True  False  False
# 907000                0    True   True  False

# %%
t_games_df = pd.get_dummies(t_games_df, columns=['windows', 'mac', 'linux'])
t_games_df = t_games_df.drop(columns=['windows_False', 'mac_False', 'linux_False'])
t_games_df.head()
# Out:
#                     name  release_date price  \
# 906850            Again?   Aug 8, 2018  0.49
# 906880              goto  Aug 17, 2018  1.99
# 906920  Political Puzzle   Aug 7, 2018  0.99
# 906950       Bomb Riders  Aug 29, 2018  1.99
# 907000     The Navigator   Aug 3, 2018   0.0
#
#                                                categories  \
# 906850                                    [Single-player]
# 906880  [Single-player, Steam Achievements, Partial Co...
# 906920                [Single-player, Steam Achievements]
# 906950                                    [Single-player]
# 907000                                    [Single-player]
#
#                                           genres recommendations  \
# 906850                                   [Indie]               0
# 906880                           [Casual, Indie]               0
# 906920                   [Action, Casual, Indie]               0
# 906950                                  [Casual]               0
# 907000  [Adventure, Casual, Free to Play, Indie]               0
#
#        metacritic_score  windows_True  mac_True  linux_True
# 906850                0             1         0           0
# 906880                0             1         0           0
# 906920                0             1         0           0
# 906950                0             1         0           0
# 907000                0             1         1           0

# %%
dupes_df = t_games_df[t_games_df.duplicated('name')]
dupes_df
# Out:
#                                                   name  release_date  price  \
# 890030   Shadow of the Tomb Raider: Definitive Edition  Sep 14, 2018    0.0
# 890031   Shadow of the Tomb Raider: Definitive Edition  Sep 14, 2018    0.0
# 890032   Shadow of the Tomb Raider: Definitive Edition  Sep 14, 2018    0.0
# 849160   Shadow of the Tomb Raider: Definitive Edition  Sep 14, 2018    0.0
# 849161   Shadow of the Tomb Raider: Definitive Edition  Sep 14, 2018    0.0
# ...                                                ...           ...    ...
# 1095360                                           Lost  Oct 10, 2019   2.99
# 1091950                                   Naughty Girl  Jun 14, 2019   0.99
# 1090690                                         Sapper  Dec 18, 2019  19.99
# 1090800                                Northern Lights  Dec 14, 2020  15.99
# 1086060                                  Tunnel Vision   Oct 8, 2019   4.99
#
#                                                 categories  \
# 890030   [Single-player, Steam Achievements, Full contr...
# 890031   [Single-player, Steam Achievements, Full contr...
# 890032   [Single-player, Steam Achievements, Full contr...
# 849160   [Single-player, Steam Achievements, Full contr...
# 849161   [Single-player, Steam Achievements, Full contr...
# ...                                                    ...
# 1095360   [Single-player, Steam Achievements, Steam Cloud]
# 1091950   [Single-player, Steam Achievements, Steam Cloud]
# 1090690             [Single-player, Includes level editor]
# 1090800                       [Single-player, Steam Cloud]
# 1086060                [Single-player, Steam Achievements]
#
#                                         genres recommendations  \
# 890030                     [Action, Adventure]           47599
# 890031                     [Action, Adventure]           47599
# 890032                     [Action, Adventure]           47599
# 849160                     [Action, Adventure]           47599
# 849161                     [Action, Adventure]           47600
# ...                                        ...             ...
# 1095360             [Adventure, Casual, Indie]               0
# 1091950                        [Casual, Indie]             110
# 1090690                                [Indie]               0
# 1090800      [Indie, Simulation, Early Access]             153
# 1086060  [Action, Casual, Indie, Early Access]               0
#
#         metacritic_score  windows_True  mac_True  linux_True
# 890030                77             1         1           1
# 890031                77             1         1           1
# 890032                77             1         1           1
# 849160                77             1         1           1
# 849161                77             1         1           1
# ...                  ...           ...       ...         ...
# 1095360                0             1         1           0
# 1091950                0             1         0           0
# 1090690                0             1         0           0
# 1090800                0             1         0           0
# 1086060                0             1         0           0
#
# [259 rows x 10 columns]

# %%
clean_df = t_games_df.drop_duplicates(subset='name')
clean_df
# Out:
#                      name  release_date price  \
# 906850             Again?   Aug 8, 2018  0.49
# 906880               goto  Aug 17, 2018  1.99
# 906920   Political Puzzle   Aug 7, 2018  0.99
# 906950        Bomb Riders  Aug 29, 2018  1.99
# 907000      The Navigator   Aug 3, 2018   0.0
# ...                   ...           ...   ...
# 1084930      Sack of Bots   Jun 6, 2019  0.99
# 1084010          Bombuzal  Aug 15, 2019  6.99
# 1084020          TheoTown   Jun 5, 2019  7.99
# 1084080  Save Daddy Trump   Jul 9, 2019   0.5
# 1084090       Kerfuffight  Aug 30, 2019  4.99
#
#                                                 categories  \
# 906850                                     [Single-player]
# 906880   [Single-player, Steam Achievements, Partial Co...
# 906920                 [Single-player, Steam Achievements]
# 906950                                     [Single-player]
# 907000                                     [Single-player]
# ...                                                    ...
# 1084930   [Single-player, Steam Achievements, Steam Cloud]
# 1084010  [Single-player, Multi-player, Co-op, Shared/Sp...
# 1084020                [Single-player, Steam Achievements]
# 1084080                [Single-player, Steam Achievements]
# 1084090  [Single-player, Multi-player, PvP, Shared/Spli...
#
#                                            genres recommendations  \
# 906850                                    [Indie]               0
# 906880                            [Casual, Indie]               0
# 906920                    [Action, Casual, Indie]               0
# 906950                                   [Casual]               0
# 907000   [Adventure, Casual, Free to Play, Indie]               0
# ...                                           ...             ...
# 1084930                           [Action, Indie]               0
# 1084010                                [Strategy]               0
# 1084020             [Indie, Simulation, Strategy]             986
# 1084080                [Adventure, Casual, Indie]               0
# 1084090                           [Action, Indie]               0
#
#         metacritic_score  windows_True  mac_True  linux_True
# 906850                 0             1         0           0
# 906880                 0             1         0           0
# 906920                 0             1         0           0
# 906950                 0             1         0           0
# 907000                 0             1         1           0
# ...                  ...           ...       ...         ...
# 1084930                0             1         0           0
# 1084010                0             1         0           1
# 1084020                0             1         1           1
# 1084080                0             1         0           0
# 1084090                0             1         0           0
#
# [41106 rows x 10 columns]

# %%
clean_df['release_date'] = pd.to_datetime(clean_df['release_date'])
clean_df
# Out:
# E:\SCHOOL\General_Utilities\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                      name release_date price  \
# 906850             Again?   2018-08-08  0.49
# 906880               goto   2018-08-17  1.99
# 906920   Political Puzzle   2018-08-07  0.99
# 906950        Bomb Riders   2018-08-29  1.99
# 907000      The Navigator   2018-08-03   0.0
# ...                   ...          ...   ...
# 1084930      Sack of Bots   2019-06-06  0.99
# 1084010          Bombuzal   2019-08-15  6.99
# 1084020          TheoTown   2019-06-05  7.99
# 1084080  Save Daddy Trump   2019-07-09   0.5
# 1084090       Kerfuffight   2019-08-30  4.99
#
#                                                 categories  \
# 906850                                     [Single-player]
# 906880   [Single-player, Steam Achievements, Partial Co...
# 906920                 [Single-player, Steam Achievements]
# 906950                                     [Single-player]
# 907000                                     [Single-player]
# ...                                                    ...
# 1084930   [Single-player, Steam Achievements, Steam Cloud]
# 1084010  [Single-player, Multi-player, Co-op, Shared/Sp...
# 1084020                [Single-player, Steam Achievements]
# 1084080                [Single-player, Steam Achievements]
# 1084090  [Single-player, Multi-player, PvP, Shared/Spli...
#
#                                            genres recommendations  \
# 906850                                    [Indie]               0
# 906880                            [Casual, Indie]               0
# 906920                    [Action, Casual, Indie]               0
# 906950                                   [Casual]               0
# 907000   [Adventure, Casual, Free to Play, Indie]               0
# ...                                           ...             ...
# 1084930                           [Action, Indie]               0
# 1084010                                [Strategy]               0
# 1084020             [Indie, Simulation, Strategy]             986
# 1084080                [Adventure, Casual, Indie]               0
# 1084090                           [Action, Indie]               0
#
#         metacritic_score  windows_True  mac_True  linux_True
# 906850                 0             1         0           0
# 906880                 0             1         0           0
# 906920                 0             1         0           0
# 906950                 0             1         0           0
# 907000                 0             1         1           0
# ...                  ...           ...       ...         ...
# 1084930                0             1         0           0
# 1084010                0             1         0           1
# 1084020                0             1         1           1
# 1084080                0             1         0           0
# 1084090                0             1         0           0
#
# [41106 rows x 10 columns]

# %%
clean_df.insert(0, 'app_id', clean_df.index)
clean_df['metacritic_score'] = pd.to_numeric(clean_df['metacritic_score'])
clean_df['recommendations'] = pd.to_numeric(clean_df['recommendations'])
clean_df['price'] = pd.to_numeric(clean_df['price'])
clean_df.dropna(axis=0, inplace=True, how='any')
clean_df
# Out:
# E:\SCHOOL\General_Utilities\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# E:\SCHOOL\General_Utilities\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# E:\SCHOOL\General_Utilities\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# E:\SCHOOL\General_Utilities\anaconda3\envs\mlenv\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#           app_id              name release_date  price  \
# 906850    906850            Again?   2018-08-08   0.49
# 906880    906880              goto   2018-08-17   1.99
# 906920    906920  Political Puzzle   2018-08-07   0.99
# 906950    906950       Bomb Riders   2018-08-29   1.99
# 907000    907000     The Navigator   2018-08-03   0.00
# ...          ...               ...          ...    ...
# 1084930  1084930      Sack of Bots   2019-06-06   0.99
# 1084010  1084010          Bombuzal   2019-08-15   6.99
# 1084020  1084020          TheoTown   2019-06-05   7.99
# 1084080  1084080  Save Daddy Trump   2019-07-09   0.50
# 1084090  1084090       Kerfuffight   2019-08-30   4.99
#
#                                                 categories  \
# 906850                                     [Single-player]
# 906880   [Single-player, Steam Achievements, Partial Co...
# 906920                 [Single-player, Steam Achievements]
# 906950                                     [Single-player]
# 907000                                     [Single-player]
# ...                                                    ...
# 1084930   [Single-player, Steam Achievements, Steam Cloud]
# 1084010  [Single-player, Multi-player, Co-op, Shared/Sp...
# 1084020                [Single-player, Steam Achievements]
# 1084080                [Single-player, Steam Achievements]
# 1084090  [Single-player, Multi-player, PvP, Shared/Spli...
#
#                                            genres  recommendations  \
# 906850                                    [Indie]                0
# 906880                            [Casual, Indie]                0
# 906920                    [Action, Casual, Indie]                0
# 906950                                   [Casual]                0
# 907000   [Adventure, Casual, Free to Play, Indie]                0
# ...                                           ...              ...
# 1084930                           [Action, Indie]                0
# 1084010                                [Strategy]                0
# 1084020             [Indie, Simulation, Strategy]              986
# 1084080                [Adventure, Casual, Indie]                0
# 1084090                           [Action, Indie]                0
#
#          metacritic_score  windows_True  mac_True  linux_True
# 906850                  0             1         0           0
# 906880                  0             1         0           0
# 906920                  0             1         0           0
# 906950                  0             1         0           0
# 907000                  0             1         1           0
# ...                   ...           ...       ...         ...
# 1084930                 0             1         0           0
# 1084010                 0             1         0           1
# 1084020                 0             1         1           1
# 1084080                 0             1         0           0
# 1084090                 0             1         0           0
#
# [41036 rows x 11 columns]

# %%
clean_df.isna().sum()
# Out:
# app_id              0
# name                0
# release_date        0
# price               0
# categories          0
# genres              0
# recommendations     0
# metacritic_score    0
# windows_True        0
# mac_True            0
# linux_True          0
# dtype: int64

# %%
clean_df.dtypes
# Out:
# app_id                       int64
# name                        object
# release_date        datetime64[ns]
# price                      float64
# categories                  object
# genres                      object
# recommendations              int64
# metacritic_score             int64
# windows_True                 uint8
# mac_True                     uint8
# linux_True                   uint8
# dtype: object

# %%
clean_df.to_csv('game_data.csv', index=False)
